# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import math

# PISA Image
pisa_bgr = cv2.imread("PISA.jpg", 1)
# converting BGR to RGB
pisa = cv2.cvtColor(pisa_bgr, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.imshow(final_img, cmap='gray')

# %%
# Detect the edges of pisa tower using trial and error method
edge = cv2.line(pisa, (128,20), (112,150), (0,0,255), 1)


plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.imshow(edge, cmap='gray')

# %%
# Find angle
h, w, c = pisa.shape
center = (h//2, w//2)
rotation_matrix = cv2.getRotationMatrix2D(center, 15, 1.0)
final_img = cv2.warpAffine(pisa, rotation_matrix, (w,h))
